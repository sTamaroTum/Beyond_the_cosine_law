# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.serif": ["Helvetica"],
})
plt.rcParams.update({'font.size': 18})

# %%
colors = plt.cm.seismic(np.linspace(0.425,0.99,4))

# %%
plt.close("all")
plt.figure(1,figsize=(9,4))
plt.subplot(2,2,1)
#
plt.plot(np.load('num_data/fig7/85ms_gamma_arr.npy'),np.load('num_data/fig7/85ms_etaT_model.npy'),'-',color='C0',label='$u_\infty=8.5$ m/s',linewidth=1.75)
plt.plot(np.load('num_data/fig7/85ms_gamma_arr.npy'),np.load('num_data/fig7/85ms_etaT_kh.npy'),'--',color='C1', label='_nolegend_')
plt.scatter(np.linspace(0,30,4),np.load('num_data/fig7/85ms_etaT_les.npy'),60,color='C0',marker='d',clip_on=False)
#
plt.plot(np.load('num_data/fig7/105ms_gamma_arr.npy'),np.load('num_data/fig7/105ms_etaT_model.npy'),'-.',color=colors[0],label='$u_\infty=10.5$ m/s',linewidth=1.75)
plt.scatter(np.linspace(0,30,4),np.load('num_data/fig7/105ms_etaT_les.npy'),60,color=colors[0],clip_on=False)
#
plt.plot(np.load('num_data/fig7/11ms_gamma_arr.npy'),np.load('num_data/fig7/11ms_etaT_model.npy'),color=colors[1],linestyle=(0, (1, 4)),label='$u_\infty=11$ m/s',linewidth=1.75)
plt.scatter(np.linspace(0,30,4),np.load('num_data/fig7/11ms_etaT_les.npy'),60,color=colors[1],marker='^',clip_on=False)
#
plt.plot(np.load('num_data/fig7/13ms_gamma_arr.npy'),np.load('num_data/fig7/13ms_etaT_model.npy'),':',color=colors[2],label='$u_\infty=13$ m/s',linewidth=1.75)
plt.scatter(np.linspace(0,30,4),np.load('num_data/fig7/13ms_etaT_les.npy'),60,color=colors[2],marker='s',clip_on=False)

# %%
plt.subplot(2,2,2)
#
plt.plot(np.load('num_data/fig7/85ms_gamma_arr.npy'),np.load('num_data/fig7/85ms_etaP_model.npy'),'-',color='C0',linewidth=1.75)
plt.plot(np.load('num_data/fig7/85ms_gamma_arr.npy'),np.load('num_data/fig7/85ms_etaP_kh.npy'),'--',color='C1',linewidth=1.75)
plt.scatter(np.linspace(0,30,4),np.load('num_data/fig7/85ms_etaP_les.npy'),60,color='C0',marker='d',clip_on=False)
#
plt.plot(np.load('num_data/fig7/105ms_gamma_arr.npy'),np.load('num_data/fig7/105ms_etaP_model.npy'),'-.',color=colors[0],linewidth=1.75)
plt.scatter(np.linspace(0,30,4),np.load('num_data/fig7/105ms_etaP_les.npy'),60,color=colors[0],clip_on=False)
#
plt.plot(np.load('num_data/fig7/11ms_gamma_arr.npy'),np.load('num_data/fig7/11ms_etaP_model.npy'),color=colors[1],linestyle=(0, (1, 4)),linewidth=1.75)
plt.scatter(np.linspace(0,30,4),np.load('num_data/fig7/11ms_etaP_les.npy'),60,color=colors[1],marker='^',clip_on=False)
#
plt.plot(np.load('num_data/fig7/13ms_gamma_arr.npy'),np.load('num_data/fig7/13ms_etaP_model.npy'),':',color=colors[2],linewidth=1.75)
plt.scatter(np.linspace(0,30,4),np.load('num_data/fig7/13ms_etaP_les.npy'),60,color=colors[2],marker='s',clip_on=False)

# %%
plt.subplot(2,2,3)
#
plt.plot(np.load('num_data/fig7/85ms_gamma_arr.npy'),np.load('num_data/fig7/85ms_paxxo_model.npy'),'-',color='C0',linewidth=1.75)
plt.scatter(np.linspace(0,30,4),np.load('num_data/fig7/85ms_paxxo_les.npy'),60,color='C0',marker='d',clip_on=False)
#
plt.plot(np.load('num_data/fig7/105ms_gamma_arr.npy'),np.load('num_data/fig7/105ms_paxxo_model.npy'),'-.',color=colors[0],linewidth=1.75)
plt.scatter(np.linspace(0,30,4),np.load('num_data/fig7/105ms_paxxo_les.npy'),60,color=colors[0],clip_on=False)
#
plt.plot(np.load('num_data/fig7/11ms_gamma_arr.npy'),np.load('num_data/fig7/11ms_paxxo_model.npy'),color=colors[1],linestyle=(0, (1, 4)),linewidth=1.75)
plt.scatter(np.linspace(0,30,4),np.load('num_data/fig7/11ms_paxxo_les.npy'),60,color=colors[1],marker='^',clip_on=False)
#
plt.plot(np.load('num_data/fig7/13ms_gamma_arr.npy'),np.load('num_data/fig7/13ms_paxxo_model.npy'),':',color=colors[2],linewidth=1.75)
plt.scatter(np.linspace(0,30,4),np.load('num_data/fig7/13ms_paxxo_les.npy'),60,color=colors[2],marker='s',clip_on=False)

# %%
plt.subplot(2,2,4)
#
plt.plot(np.load('num_data/fig7/85ms_gamma_arr.npy'),np.load('num_data/fig7/85ms_tsr_model.npy'),'-',color='C0',linewidth=1.75)
plt.scatter(np.linspace(0,30,4),np.load('num_data/fig7/85ms_tsr_les.npy'),60,color='C0',marker='d',clip_on=False)
#
plt.plot(np.load('num_data/fig7/105ms_gamma_arr.npy'),np.load('num_data/fig7/105ms_tsr_model.npy'),'-.',color=colors[0],linewidth=1.75)
plt.scatter(np.linspace(0,30,4),np.load('num_data/fig7/105ms_tsr_les.npy'),60,color=colors[0],clip_on=False)
#
plt.plot(np.load('num_data/fig7/11ms_gamma_arr.npy'),np.load('num_data/fig7/11ms_tsr_model.npy'),color=colors[1],linestyle=(0, (1, 4)),linewidth=1.75)
plt.scatter(np.linspace(0,30,4),np.load('num_data/fig7/11ms_tsr_les.npy'),60,color=colors[1],marker='^',clip_on=False)
#
plt.plot(np.load('num_data/fig7/13ms_gamma_arr.npy'),np.load('num_data/fig7/13ms_tsr_model.npy'),':',color=colors[2],linewidth=1.75)
plt.scatter(np.linspace(0,30,4),np.load('num_data/fig7/13ms_tsr_les.npy'),60,color=colors[2],marker='s',clip_on=False)
##
plt.subplot(2,2,1)
plt.xticks([0,10,20,30],color='w')
plt.ylim([0.8,1.4])
plt.xlim([0,30])
plt.text(1.5,1.25,'(a)')
plt.yticks([0.8,1,1.2,1.4])
plt.ylabel('$\eta_T$ [-]')
plt.legend(ncol=4,loc='lower left',bbox_to_anchor=(-0.275,0.94),frameon=False,handlelength=1.75,handletextpad=0.4,columnspacing=1.2)
plt.grid()
plt.subplot(2,2,2)
plt.text(1.5,0.925,'(b)')
plt.xlim([0,30])
plt.xticks([0,10,20,30],color='w')
plt.ylim([0.7,1.01])
plt.yticks([0.7,0.8,0.9,1])
plt.ylabel('$\eta_P$ [-]')
plt.grid()
plt.subplot(2,2,3)
plt.text(27,9.7,'(c)')
plt.xlim([0,30])
plt.xticks([0,10,20,30],color='k')
plt.ylim([0,12])
plt.yticks([0,4,8,12])
plt.ylabel(r'$\theta_p$ [$^\circ$]')
plt.xlabel('$\gamma$ [$^\circ$]')
plt.grid()
plt.subplot(2,2,4)
plt.text(27,7.6,'(d)')
plt.xlim([0,30])
plt.xticks([0,10,20,30],color='k')
plt.ylim([6,8])
plt.yticks([6,7,8])
plt.ylabel('$\lambda$ [-]')
plt.xlabel('$\gamma$ [$^\circ$]')
plt.grid()
plt.subplots_adjust(left=0.1, bottom=0.175, right=0.95, top=0.9, wspace=0.3, hspace=0.2)
# plt.savefig('figure_R2_R3.png',dpi=350)
