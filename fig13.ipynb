# %% [markdown]
# # Validation of the simplified choice of model parameters with different wind turbine models

# %% [markdown]
#  This is an interactive version of Figure 13 found in Tamaro et al (in review).

# %% [markdown]
# ## Code

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.figure(1,figsize=(9,4.0))
plt.subplot(1,2,1)
plt.scatter(np.load('num_data/fig13/NREL5MW_gammaARR.npy'),np.load('num_data/fig13/NREL5MW_CT0.npy')/np.load('num_data/fig13/NREL5MW_CT0.npy')[0],45,marker='^',color='C2',clip_on=False)
plt.plot(np.load('num_data/fig13/NREL5MW_gammaARR.npy'),np.load('num_data/fig13/NREL5MW_etaT0.npy')/np.load('num_data/fig13/NREL5MW_etaT0.npy')[0],color='C2',linewidth=1.75,clip_on=False,label=r'NREL 5MW $\theta_p=0^\circ$')
#
plt.scatter(np.load('num_data/fig13/NREL5MW_gammaARR.npy'),np.load('num_data/fig13/NREL5MW_CT5.npy')/np.load('num_data/fig13/NREL5MW_CT5.npy')[0],45,marker='^',color='C3',clip_on=False)
plt.plot(np.load('num_data/fig13/NREL5MW_gammaARR.npy'),np.load('num_data/fig13/NREL5MW_etaT5.npy')/np.load('num_data/fig13/NREL5MW_etaT5.npy')[0],':',color='C3',linewidth=1.75,clip_on=False,label=r'NREL 5MW $\theta_p=5^\circ$')
#
plt.scatter(np.load('num_data/fig13/NREL5MW_gammaARR.npy'),np.load('num_data/fig13/G178_CT0.npy')/np.load('num_data/fig13/G178_CT0.npy')[0],45,marker='^',color='C6',clip_on=False)
plt.plot(np.load('num_data/fig13/NREL5MW_gammaARR.npy'),np.load('num_data/fig13/G178_etaT0.npy')/np.load('num_data/fig13/G178_etaT0.npy')[0],'--',linewidth=1.75,color='C6',clip_on=False,label=r'G178 $\theta_p=-1.6^\circ$')
#
plt.scatter(np.load('num_data/fig13/NREL5MW_gammaARR.npy'),np.load('num_data/fig13/G178_CT5.npy')/np.load('num_data/fig13/G178_CT5.npy')[0],45,marker='^',color='c',clip_on=False)
plt.plot(np.load('num_data/fig13/NREL5MW_gammaARR.npy'),np.load('num_data/fig13/G178_etaT5.npy')/np.load('num_data/fig13/G178_etaT5.npy')[0],'-.',linewidth=1.75,color='c',clip_on=False,label=r'G178 $\theta_p=6.5^\circ$')
#################
plt.subplot(1,2,2)
plt.scatter(np.load('num_data/fig13/NREL5MW_gammaARR.npy'),np.load('num_data/fig13/NREL5MW_POW0.npy')/np.load('num_data/fig13/NREL5MW_POW0.npy')[0],45,marker='^',color='C2',clip_on=False)
plt.plot(np.load('num_data/fig13/NREL5MW_gammaARR.npy'),np.load('num_data/fig13/NREL5MW_etaP0.npy')/np.load('num_data/fig13/NREL5MW_etaP0.npy')[0],color='C2',linewidth=1.75,clip_on=False)
#
plt.scatter(np.load('num_data/fig13/NREL5MW_gammaARR.npy'),np.load('num_data/fig13/NREL5MW_POW5.npy')/np.load('num_data/fig13/NREL5MW_POW5.npy')[0],45,marker='^',color='C3',clip_on=False)
plt.plot(np.load('num_data/fig13/NREL5MW_gammaARR.npy'),np.load('num_data/fig13/NREL5MW_etaP5.npy')/np.load('num_data/fig13/NREL5MW_etaP5.npy')[0],':',color='C3',linewidth=1.75,clip_on=False)
#
plt.scatter(np.load('num_data/fig13/NREL5MW_gammaARR.npy'),np.load('num_data/fig13/G178_POW0.npy')/np.load('num_data/fig13/G178_POW0.npy')[0],45,marker='^',color='C6',clip_on=False)
plt.plot(np.load('num_data/fig13/NREL5MW_gammaARR.npy'),np.load('num_data/fig13/G178_etaP0.npy')/np.load('num_data/fig13/G178_etaP0.npy')[0],'--',linewidth=1.75,color='C6',clip_on=False)
#
plt.scatter(np.load('num_data/fig13/NREL5MW_gammaARR.npy'),np.load('num_data/fig13/G178_POW5.npy')/np.load('num_data/fig13/G178_POW5.npy')[0],45,marker='^',color='c',clip_on=False)
plt.plot(np.load('num_data/fig13/NREL5MW_gammaARR.npy'),np.load('num_data/fig13/G178_etaP5.npy')/np.load('num_data/fig13/G178_etaP5.npy')[0],'-.',linewidth=1.75,color='c',clip_on=False)
#
plt.subplot(1,2,1)
plt.xlim([0,30])
plt.xticks(np.linspace(0,30,4))
plt.ylim([0.78,1])
plt.yticks(np.linspace(0.8,1,3))
plt.xlabel('$\gamma$ [$^\circ$]')
plt.ylabel('$\eta_T$ [-]')
plt.text(25,0.965,'(a)')
plt.grid()
plt.legend(ncol=2,bbox_to_anchor=(0.2,1.4),frameon=False,columnspacing=2.5,handlelength=1.6,loc='upper left')
plt.subplot(1,2,2)
plt.xlim([0,30])
plt.xticks(np.linspace(0,30,4))
plt.ylim([0.68,1])
plt.yticks(np.linspace(0.7,1,4))
plt.xlabel('$\gamma$ [$^\circ$]')
plt.ylabel('$\eta_P$ [-]')
plt.text(25,0.945,'(b)')
plt.grid()
plt.subplots_adjust(left=0.1, bottom=0.2, right=0.95, top=0.8, wspace=0.25, hspace=0)
